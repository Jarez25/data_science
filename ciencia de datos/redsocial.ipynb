# %%
# Lista de usuarios
users = [
    {"id": 0, "name": "Hero"},
    {"id": 1, "name": "Dunn"},
    {"id": 2, "name": "Sue"},
    {"id": 3, "name": "Chi"},
    {"id": 4, "name": "Thor"},
    {"id": 5, "name": "Clive"},
    {"id": 6, "name": "Hicks"},
    {"id": 7, "name": "Devin"},
    {"id": 8, "name": "Kate"},
    {"id": 9, "name": "Klein"},
]

# %%
# Lista de pares de amistad
amistades_pares = [
    (0, 1), (0, 2), (1, 2), (1, 3), (2, 3), (3, 4),
    (4, 5), (5, 6), (5, 7), (6, 8), (7, 8), (8, 9)
]

# %% [markdown]
# def foaf_ids_bad(user):
#     return [
#         foaf_id
#         for friend_id in friendship[user["id"]]
#         for foaf_id in friendship[friend_id]
#     ]

# %% [markdown]
# ![image.png](attachment:1aa756a9-7591-43ed-b3a9-f304505b7e08.png)

# %%
usuario = 1

usuario = 1

print('las amistades del usuario ' + str(usuario) + ': ')

for i,j in amistades_pares:
    if usuario in (i,j):
        if i != usuario:
            print(i)
        elif j != usuario:
            print(j)
# Out:
# las amistades del usuario 1:
# 0
# 2
# 3
