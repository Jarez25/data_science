# %%
import pandas as pd

# %%
df = pd.read_csv('estudiantes.csv')

# %%
df
# Out:
#   NOMBRE  EDAD GENERO      CARRERA SEMESTRE
# 0  Jairo    28      M  Informatica  Primero
# 1  Jarez    28      M  Informatica  Primero
# 2  Ailen     2      F     Medicina  Primero
# 3  Juvel    25      F       Dibujo   Quinto
# 4   Sara    38      F       Ventas   Cuarto
# 5  Sofia    44      F      Derecho  Segundo

# %%
df.iloc[1,3]
df.loc[4,'EDAD']
# Out:
# 38

# %%
df.iloc[2,:3]
# Out:
# NOMBRE    Ailen
# EDAD          2
# GENERO        F
# Name: 2, dtype: object

# %%
df['TURNO'] = pd.Series(['tarde','noche','tarde', ' noche', 'tarde', 'noche'])

# %%
df
# Out:
#   NOMBRE  EDAD GENERO      CARRERA SEMESTRE   TURNO
# 0  Jairo    28      M  Informatica  Primero   tarde
# 1  Jarez    28      M  Informatica  Primero   noche
# 2  Ailen     2      F     Medicina  Primero   tarde
# 3  Juvel    25      F       Dibujo   Quinto   noche
# 4   Sara    38      F       Ventas   Cuarto   tarde
# 5  Sofia    44      F      Derecho  Segundo   noche

# %%
SEMESTRE = df.pop('SEMESTRE')

# %%
df
# Out:
#   NOMBRE  EDAD GENERO      CARRERA   TURNO
# 0  Jairo    28      M  Informatica   tarde
# 1  Jarez    28      M  Informatica   noche
# 2  Ailen     2      F     Medicina   tarde
# 3  Juvel    25      F       Dibujo   noche
# 4   Sara    38      F       Ventas   tarde
# 5  Sofia    44      F      Derecho   noche

# %%
new_row = pd.DataFrame([['mayling', 25, 'F', 'Panadera', 'diurno']],
                       columns=['NOMBRE', 'EDAD', 'GENERO', 'CARRERA', 'TURNO'])

# %%
df = pd.concat([df, new_row], ignore_index=True)

# %%
df
# Out:
#     NOMBRE  EDAD GENERO      CARRERA   TURNO
# 0    Jairo    28      M  Informatica   tarde
# 1    Jarez    28      M  Informatica   noche
# 2    Ailen     2      F     Medicina   tarde
# 3    Juvel    25      F       Dibujo   noche
# 4     Sara    38      F       Ventas   tarde
# 5    Sofia    44      F      Derecho   noche
# 6  mayling    25      F     Panadera  diurno
# 7  mayling    25      F     Panadera  diurno

# %%
df.drop([7])
# Out:
#     NOMBRE  EDAD GENERO      CARRERA   TURNO
# 0    Jairo    28      M  Informatica   tarde
# 1    Jarez    28      M  Informatica   noche
# 2    Ailen     2      F     Medicina   tarde
# 3    Juvel    25      F       Dibujo   noche
# 4     Sara    38      F       Ventas   tarde
# 5    Sofia    44      F      Derecho   noche
# 6  mayling    25      F     Panadera  diurno

# %%
df[(df['GENERO']=='F') & (df['EDAD'] > 30)]
# Out:
#   NOMBRE  EDAD GENERO  CARRERA  TURNO
# 4   Sara    38      F   Ventas  tarde
# 5  Sofia    44      F  Derecho  noche

# %%
df.sort_values('CARRERA')
# Out:
#     NOMBRE  EDAD GENERO      CARRERA   TURNO
# 5    Sofia    44      F      Derecho   noche
# 3    Juvel    25      F       Dibujo   noche
# 0    Jairo    28      M  Informatica   tarde
# 1    Jarez    28      M  Informatica   noche
# 2    Ailen     2      F     Medicina   tarde
# 6  mayling    25      F     Panadera  diurno
# 7  mayling    25      F     Panadera  diurno
# 4     Sara    38      F       Ventas   tarde

# %%
df.sort_values('EDAD')
df.dropna()#excluyes los valores NAN
# Out:
#     NOMBRE  EDAD GENERO      CARRERA   TURNO
# 2    Ailen     2      F     Medicina   tarde
# 3    Juvel    25      F       Dibujo   noche
# 6  mayling    25      F     Panadera  diurno
# 7  mayling    25      F     Panadera  diurno
# 0    Jairo    28      M  Informatica   tarde
# 1    Jarez    28      M  Informatica   noche
# 4     Sara    38      F       Ventas   tarde
# 5    Sofia    44      F      Derecho   noche
